# %% [markdown]
# <a href="https://colab.research.google.com/github/JPedroPV/COMP5600FINAL/blob/main/Sudoku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import csv
import random
import time

class Sudoku:
  board: np.array([])
  solution: np.array([])

  #Inititalize Sudoku Board Object
  def __init__(self, initBoard, solved):
    initBoard = [int(x) for x in list(initBoard)]
    solved = [int(x) for x in list(solved)]
    self.board = np.reshape(initBoard, (9,9))
    self.solution = np.reshape(solved, (9,9))

  #Print Sudoku Board
  def printBoard(self):
    for i in range(9):
      if i % 3 == 0 and i != 0:
        print("---------------------")
      for j in range(9):
        if j % 3 == 0 and j != 0:
          print("| ", end="")
        print(self.board[i][j], end=" ")
      print()
    print()

  #Print Sudoku Solution
  def printSolution(self):
    for i in range(9):
      if i % 3 == 0 and i != 0:
        print("---------------------")
      for j in range(9):
        if j % 3 == 0 and j != 0:
          print("| ", end="")
        print(self.solution[i][j], end=" ")
      print()

  #Update Sudoku Cell
  def updateCell(self, row, col, val):
    self.board[row][col] = val

  #Check if Sudoku Cell is Valid
  def checkCell(self, row, col):
    val = self.board[row][col]
    if self.board[row][col] == 0:
      #print("Empty Cell")
      return False
    for i in range(9):
      if self.board[row][i] == val and i != col:
        #print("Row Violation")
        return False
      if self.board[i][col] == val and i != row:
        #print("Column Violation")
        return False
    for i in range(3):
      for j in range(3):
        if self.board[row//3*3+i][col//3*3+j] == val and i != row and j != col:
          #print("Subcell Violation")
          return False
    return True

  #Check if Sudoku Cell is Valid with given Value
  def checkCellVal(self, row, col, val):
    for i in range(9):
      if self.board[row][i] == val and i != col:
        print("Row Violation for value: " + str(val))
        return False
      if self.board[i][col] == val and i != row:
        print("Column Violation for value: " + str(val))
        return False
    for i in range(3):
      for j in range(3):
        if self.board[row//3*3+i][col//3*3+j] == val and i != row and j != col:
          print("Subcell Violation for value: " + str(val))
          return False
    return True

  #Check a cell's possible values given current state of board
  def possNum(self, row, col):
    nums = []
    for i in range(1, 10):
      if self.checkCellVal(row, col, i):
        nums.append(i)
    return nums

  def checkArc():
    start = time.time()
    end = time.time()
    print("Time taken:", end-start)

  def checkForward():
    start = time.time()
    end = time.time()
    print("Time taken:", end-start)

  def checkMin():
    start = time.time()
    end = time.time()
    print("Time taken:", end-start)

  def checkMCV():
    start = time.time()
    end = time.time()
    print("Time taken:", end-start)

#Main
data = []
solution = []
with open('sudoku.csv', newline='') as csvFile:
  reader = csv.reader(csvFile)
  next(reader)
  count = 10
  while count > 0:
    chance = random.random()
    if chance > 0.0:
      board = next(reader)
      data.append(board[0])
      solution.append(board[1])
      count -= 1
    else:
      next(reader)
boards = []
for i in range(len(data)):
  boards.append(Sudoku(data[i], solution[i]))

# for i in range(len(data)):
#   print("Board", i+1)
#   boards[i].printBoard()
#   print()
#   print("Solution")
#   boards[i].printSolution()
#   print()

# #checkCell() testing
# help = boards[1]
# help.printBoard()
# print(help.checkCell(0, 0))
# print()
# help.updateCell(0, 0, 0)
# help.printBoard()
# print(help.checkCell(0, 0))
# print()
# help.updateCell(0, 0, 1)
# help.printBoard()
# print(help.checkCell(0, 0))
# print()
# help.updateCell(2, 5, 6)
# help.printBoard()
# print(help.checkCell(2, 5))
# print()
# help.updateCell(6, 1, 7)
# help.printBoard()
# print(help.checkCell(6, 1))
# print()

#checkCellVal testing
help = boards[1]
help.printBoard()
print(help.possNum(3, 4))
print()
# Out:
# 3 0 1 | 0 8 6 | 5 0 4
# 0 4 6 | 5 2 1 | 0 7 0
# 5 0 0 | 0 0 0 | 0 0 1
# ---------------------
# 4 0 0 | 8 0 0 | 0 0 2
# 0 8 0 | 3 4 7 | 9 0 0
# 0 0 9 | 0 5 0 | 0 3 8
# ---------------------
# 0 0 4 | 0 9 0 | 2 0 0
# 0 0 8 | 7 3 4 | 0 9 0
# 0 0 7 | 2 0 8 | 1 0 3
#
# Column Violation for value: 2
# Column Violation for value: 3
# Row Violation for value: 4
# Column Violation for value: 5
# Subcell Violation for value: 7
# Column Violation for value: 8
# Column Violation for value: 9
# [1, 6]
